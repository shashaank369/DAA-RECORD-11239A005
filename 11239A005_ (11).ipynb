# %%
def fibonacci(n):
  a,b=0,1
  count=0
  while count<n:
    print(a,end=" ")
    a,b=b,a+b
    count+=1
num=int(input("enter the values:"))
if num<0:
    print("enter the non negetive value:")
else:
    fibonacci(num)
# Out:
# enter the values:2
# 0 1
